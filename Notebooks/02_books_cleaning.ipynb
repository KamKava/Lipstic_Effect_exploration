# %%
# In this notebook: 
#   load books dataset
#   clean titles/columns
#   handle missing values
#   standardise country/year format
#   check distribution of sales
#   output:
#       books_clean.csv
