# %%
# load kaggle GDP dataset and clean missing values
import pandas as pd
import numpy as np
import os
#print(os.getcwd())
# load dataset
df = pd.read_csv(r'c:\Users\cgx\My_projects\Power_BI\Lipstick_Effect_on_Books\data\raw\world_gdp_raw.csv')

# check for missing values
print(df.isnull().sum())
# Out:
# Entity                                                                  0
# Code                                                                    0
# Year                                                                    0
# World GDP in 2011 Int.$ (OWID based on World Bank & Maddison (2017))    0
# dtype: int64
